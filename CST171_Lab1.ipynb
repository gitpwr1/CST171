# %% [markdown]
# <a href="https://colab.research.google.com/github/gitpwr1/CST171/blob/main/CST171_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 1: Python Fundamentals - Variables, Loops, and Conditions**

# %% [markdown]
# **Part 1: Variables and Data Types**
#
# **Exercise 1.1: Basic Variable Declaration**
#
# Create variables for the following information:
#
#
#
#
# *   Your name as a string
# *   Your age as an integer
#
#
# *   Your height in meters as a float
# *   A boolean indicating whether you're enrolled in a computer science program
#
# Print each variable and its type using the type() function.

# %%
name = input("What's your name? ")
age = int(input("What is your AGE? "))
height = float(input("What is your height? "))
print(f"{type(name)=}")
print(f"{type(age)=}")
print(f"{type(height)=}")
# Out:
# What's your name? John
# What is your AGE? 21
# What is your height? 180
# type(name)=<class 'str'>
# type(age)=<class 'int'>
# type(height)=<class 'float'>

# %% [markdown]
# **Exercise 1.2: Variable Operations**
# Using your variables from Exercise 1.1:
# 1. Create a new variable that contains your full name and program of study as a
# formatted string
# 2. Calculate and store your age in days (approximate)
# 3. Convert your height to feet (1 meter = 3.28084 feet)
# 4. Create a variable that stores the result of a comparison between your age and 21
# Print all results with appropriate labels.

# %%
name = input("What's your full name? ")
age = int(input("What is your AGE? "))
height = float(input("What is your height? Cm "))
program = input("What's your study program? ")
profile_info = f"Name: {name} | Program of Study: {program}"

age_in_days = age * 365.25

height_in_feet = height * 3.28084

is_older_than_21 = age > 21

print("--- Personal Profile Information ---")
print(profile_info)
print(f"Approximate age in days: {age_in_days:,.0f} days")
print(f"Height: {height_in_feet:.2f} feet")
print(f"Is older than 21? {is_older_than_21}")
# Out:
# What's your full name? john
# What is your AGE? 25
# What is your height? Cm 1.80
# What's your study program? Comp Sci
# --- Personal Profile Information ---
# Name: john | Program of Study: Comp Sci
# Approximate age in days: 9,131 days
# Height: 5.91 feet
# Is older than 21? True

# %%
# 1. Full name and program of study as a formatted string
name = "Alex Morgan"
program = "Computer Science"
profile_info = f"Name: {name} | Program of Study: {program}"

age_years = 20
age_in_days = age * 365.25

height_meters = 1.75
height_in_feet = height_meters * 3.28084

is_older_than_21 = age_years > 21

print("--- Personal Profile Information ---")
print(profile_info)
print(f"Approximate age in days: {age_in_days:,.0f} days")
print(f"Height: {height_in_feet:.2f} feet")
print(f"Is older than 21? {is_older_than_21}")
# Out:
# --- Personal Profile Information ---
# Name: Alex Morgan | Program of Study: Computer Science
# Approximate age in days: 7,305 days
# Height: 5.74 feet
# Is older than 21? False
